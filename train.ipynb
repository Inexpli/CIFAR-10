# %% [markdown]
# Top accuracy: 82.26%
# <hr>
# Epochs: 130
#
# ```python
#
# optimizer = optim.Adam(net.parameters(), lr=0.001)
#
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)
#
# transform = transforms.Compose([
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(10),
#     transforms.ToTensor(),
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])
#
# class NeuralNet(nn.Module):
#     def __init__(self):
#         super(NeuralNet, self).__init__()
#         self.conv1 = nn.Conv2d(3, 64, 3)
#         self.conv2 = nn.Conv2d(64, 128, 3)
#         self.conv3 = nn.Conv2d(128, 256, 3)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.fc1 = nn.Linear(256 * 2 * 2, 512)
#         self.fc2 = nn.Linear(512, 256)
#         self.fc3 = nn.Linear(256, 10)
#         self.dropout = nn.Dropout(0.5)
#
#     def forward(self, x):
#         x = F.relu(self.conv1(x))
#         x = self.pool(x)
#         x = F.relu(self.conv2(x))
#         x = self.pool(x)
#         x = F.relu(self.conv3(x))
#         x = self.pool(x)
#         x = torch.flatten(x, 1)
#         x = F.relu(self.fc1(x))
#         x = self.dropout(x)
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x
#
# ```

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print("HIP version:", torch.version.hip)
print("Device count:", torch.cuda.device_count())
print("Device 0:", torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# HIP version: 6.2.41133-dd7f95766
# Device count: 1
# Device 0: AMD Radeon RX 6800

# %%
import numpy as np
from PIL import Image
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import random_split, DataLoader
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_data = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_data = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Podzielmy testowy zbiór na walidacyjny i testowy
val_size = 5000
test_size = len(test_data) - val_size

val_data, test_data = random_split(test_data, [val_size, test_size])

train_loader = DataLoader(train_data, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False, num_workers=2)

print(f'Training dataset: {len(train_loader.dataset)}')
print(f'Validation dataset: {len(val_loader.dataset)}')
print(f'Test dataset: {len(test_loader.dataset)}')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training dataset: 50000
# Validation dataset: 5000
# Test dataset: 5000

# %%
image, label = train_data[0]

# %%
image.size()
# Out:
# torch.Size([3, 32, 32])

# %%
class_names = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
class NeuralNet(nn.Module):
    def __init__(self):
        super(NeuralNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3)
        self.conv2 = nn.Conv2d(64, 128, 3)
        self.conv3 = nn.Conv2d(128, 256, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(256 * 2 * 2, 512)  
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
net = NeuralNet().to(device)
loss_function = nn.CrossEntropyLoss()

optimizer = optim.Adam(net.parameters(), lr=0.001)

scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.5)

torch.manual_seed(42)

# %%
num_of_epochs = 130

highest_val_accuracy = 0.0

for epoch in range(num_of_epochs):
    net.train()
    
    running_loss = 0.0

    # Trening
    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()

        outputs = net(inputs)
        loss = loss_function(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)

    net.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = net(inputs)
            loss = loss_function(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = 100 * correct / total

    scheduler.step()

    if val_accuracy > highest_val_accuracy:
        highest_val_accuracy = val_accuracy

    print(f'Epoch ({epoch + 1}/{num_of_epochs}), '
          f'Train Loss: {avg_train_loss:.4f}, '
          f'Val Loss: {avg_val_loss:.4f}, '
          f'Val Accuracy: {val_accuracy:.2f}%')

print(f'Highest Validation Accuracy: {highest_val_accuracy:.2f}%')
# Out:
# Epoch (1/130), Train Loss: 1.5398, Val Loss: 1.1832, Val Accuracy: 57.02%
# Epoch (2/130), Train Loss: 1.1594, Val Loss: 1.0258, Val Accuracy: 63.42%
# Epoch (3/130), Train Loss: 1.0088, Val Loss: 0.9366, Val Accuracy: 66.60%
# Epoch (4/130), Train Loss: 0.9145, Val Loss: 0.8751, Val Accuracy: 69.40%
# Epoch (5/130), Train Loss: 0.8580, Val Loss: 0.8673, Val Accuracy: 69.40%
# Epoch (6/130), Train Loss: 0.8032, Val Loss: 0.8018, Val Accuracy: 72.24%
# Epoch (7/130), Train Loss: 0.7725, Val Loss: 0.7786, Val Accuracy: 73.38%
# Epoch (8/130), Train Loss: 0.7396, Val Loss: 0.8093, Val Accuracy: 72.20%
# Epoch (9/130), Train Loss: 0.7192, Val Loss: 0.7589, Val Accuracy: 73.70%
# Epoch (10/130), Train Loss: 0.7014, Val Loss: 0.7715, Val Accuracy: 73.18%
# Epoch (11/130), Train Loss: 0.6791, Val Loss: 0.7073, Val Accuracy: 76.52%
# Epoch (12/130), Train Loss: 0.6636, Val Loss: 0.7399, Val Accuracy: 74.60%
# Epoch (13/130), Train Loss: 0.6548, Val Loss: 0.6998, Val Accuracy: 75.82%
# Epoch (14/130), Train Loss: 0.6376, Val Loss: 0.7173, Val Accuracy: 74.82%
# Epoch (15/130), Train Loss: 0.6247, Val Loss: 0.6796, Val Accuracy: 76.26%
# Epoch (16/130), Train Loss: 0.6113, Val Loss: 0.6820, Val Accuracy: 77.46%
# Epoch (17/130), Train Loss: 0.6052, Val Loss: 0.7209, Val Accuracy: 75.40%
# Epoch (18/130), Train Loss: 0.5982, Val Loss: 0.6928, Val Accuracy: 76.56%
# Epoch (19/130), Train Loss: 0.5843, Val Loss: 0.7195, Val Accuracy: 75.66%
# Epoch (20/130), Train Loss: 0.5812, Val Loss: 0.6752, Val Accuracy: 77.24%
# Epoch (21/130), Train Loss: 0.5710, Val Loss: 0.6976, Val Accuracy: 76.42%
# Epoch (22/130), Train Loss: 0.5731, Val Loss: 0.6885, Val Accuracy: 76.66%
# Epoch (23/130), Train Loss: 0.5546, Val Loss: 0.6578, Val Accuracy: 77.88%
# Epoch (24/130), Train Loss: 0.5473, Val Loss: 0.6825, Val Accuracy: 76.78%
# Epoch (25/130), Train Loss: 0.5428, Val Loss: 0.6639, Val Accuracy: 77.94%
# Epoch (26/130), Train Loss: 0.5400, Val Loss: 0.6509, Val Accuracy: 78.58%
# Epoch (27/130), Train Loss: 0.5336, Val Loss: 0.6605, Val Accuracy: 77.48%
# Epoch (28/130), Train Loss: 0.5278, Val Loss: 0.6619, Val Accuracy: 77.86%
# Epoch (29/130), Train Loss: 0.5228, Val Loss: 0.6714, Val Accuracy: 77.18%
# Epoch (30/130), Train Loss: 0.5093, Val Loss: 0.6735, Val Accuracy: 78.10%
# Epoch (31/130), Train Loss: 0.4420, Val Loss: 0.6251, Val Accuracy: 78.88%
# Epoch (32/130), Train Loss: 0.4308, Val Loss: 0.6076, Val Accuracy: 79.70%
# Epoch (33/130), Train Loss: 0.4145, Val Loss: 0.6252, Val Accuracy: 79.74%
# Epoch (34/130), Train Loss: 0.4084, Val Loss: 0.6277, Val Accuracy: 79.30%
# Epoch (35/130), Train Loss: 0.4033, Val Loss: 0.6307, Val Accuracy: 79.12%
# Epoch (36/130), Train Loss: 0.3933, Val Loss: 0.6107, Val Accuracy: 79.96%
# Epoch (37/130), Train Loss: 0.3880, Val Loss: 0.6378, Val Accuracy: 79.82%
# Epoch (38/130), Train Loss: 0.3862, Val Loss: 0.6317, Val Accuracy: 79.38%
# Epoch (39/130), Train Loss: 0.3748, Val Loss: 0.6085, Val Accuracy: 79.96%
# Epoch (40/130), Train Loss: 0.3753, Val Loss: 0.6103, Val Accuracy: 80.56%
# Epoch (41/130), Train Loss: 0.3774, Val Loss: 0.6281, Val Accuracy: 80.02%
# Epoch (42/130), Train Loss: 0.3666, Val Loss: 0.6129, Val Accuracy: 80.28%
# Epoch (43/130), Train Loss: 0.3651, Val Loss: 0.6199, Val Accuracy: 80.36%
# Epoch (44/130), Train Loss: 0.3520, Val Loss: 0.6154, Val Accuracy: 80.50%
# Epoch (45/130), Train Loss: 0.3587, Val Loss: 0.6178, Val Accuracy: 79.88%
# Epoch (46/130), Train Loss: 0.3517, Val Loss: 0.6352, Val Accuracy: 80.42%
# Epoch (47/130), Train Loss: 0.3501, Val Loss: 0.6436, Val Accuracy: 80.46%
# Epoch (48/130), Train Loss: 0.3453, Val Loss: 0.6159, Val Accuracy: 80.78%
# Epoch (49/130), Train Loss: 0.3396, Val Loss: 0.6219, Val Accuracy: 80.24%
# Epoch (50/130), Train Loss: 0.3406, Val Loss: 0.6043, Val Accuracy: 80.58%
# Epoch (51/130), Train Loss: 0.3433, Val Loss: 0.6012, Val Accuracy: 80.52%
# Epoch (52/130), Train Loss: 0.3359, Val Loss: 0.6455, Val Accuracy: 79.90%
# Epoch (53/130), Train Loss: 0.3252, Val Loss: 0.6297, Val Accuracy: 80.22%
# Epoch (54/130), Train Loss: 0.3319, Val Loss: 0.6366, Val Accuracy: 79.94%
# Epoch (55/130), Train Loss: 0.3304, Val Loss: 0.6336, Val Accuracy: 80.32%
# Epoch (56/130), Train Loss: 0.3216, Val Loss: 0.6568, Val Accuracy: 79.94%
# Epoch (57/130), Train Loss: 0.3220, Val Loss: 0.6264, Val Accuracy: 80.44%
# Epoch (58/130), Train Loss: 0.3269, Val Loss: 0.6272, Val Accuracy: 80.78%
# Epoch (59/130), Train Loss: 0.3250, Val Loss: 0.6125, Val Accuracy: 80.38%
# Epoch (60/130), Train Loss: 0.3140, Val Loss: 0.6417, Val Accuracy: 79.88%
# Epoch (61/130), Train Loss: 0.2827, Val Loss: 0.6305, Val Accuracy: 81.48%
# Epoch (62/130), Train Loss: 0.2724, Val Loss: 0.6430, Val Accuracy: 81.36%
# Epoch (63/130), Train Loss: 0.2667, Val Loss: 0.6419, Val Accuracy: 81.14%
# Epoch (64/130), Train Loss: 0.2613, Val Loss: 0.6561, Val Accuracy: 80.46%
# Epoch (65/130), Train Loss: 0.2599, Val Loss: 0.6642, Val Accuracy: 80.76%
# Epoch (66/130), Train Loss: 0.2566, Val Loss: 0.6399, Val Accuracy: 81.50%
# Epoch (67/130), Train Loss: 0.2643, Val Loss: 0.6460, Val Accuracy: 81.20%
# Epoch (68/130), Train Loss: 0.2504, Val Loss: 0.6368, Val Accuracy: 81.20%
# Epoch (69/130), Train Loss: 0.2544, Val Loss: 0.6415, Val Accuracy: 81.66%
# Epoch (70/130), Train Loss: 0.2452, Val Loss: 0.6573, Val Accuracy: 80.60%
# Epoch (71/130), Train Loss: 0.2499, Val Loss: 0.6668, Val Accuracy: 80.58%
# Epoch (72/130), Train Loss: 0.2478, Val Loss: 0.6395, Val Accuracy: 80.76%
# Epoch (73/130), Train Loss: 0.2420, Val Loss: 0.6611, Val Accuracy: 81.54%
# Epoch (74/130), Train Loss: 0.2392, Val Loss: 0.6611, Val Accuracy: 81.10%
# Epoch (75/130), Train Loss: 0.2404, Val Loss: 0.6690, Val Accuracy: 81.24%
# Epoch (76/130), Train Loss: 0.2420, Val Loss: 0.6711, Val Accuracy: 80.26%
# Epoch (77/130), Train Loss: 0.2386, Val Loss: 0.6326, Val Accuracy: 81.40%
# Epoch (78/130), Train Loss: 0.2328, Val Loss: 0.6665, Val Accuracy: 81.40%
# Epoch (79/130), Train Loss: 0.2333, Val Loss: 0.6721, Val Accuracy: 81.32%
# Epoch (80/130), Train Loss: 0.2357, Val Loss: 0.6674, Val Accuracy: 81.46%
# Epoch (81/130), Train Loss: 0.2301, Val Loss: 0.6881, Val Accuracy: 81.18%
# Epoch (82/130), Train Loss: 0.2290, Val Loss: 0.6894, Val Accuracy: 80.84%
# Epoch (83/130), Train Loss: 0.2255, Val Loss: 0.7027, Val Accuracy: 80.46%
# Epoch (84/130), Train Loss: 0.2201, Val Loss: 0.6636, Val Accuracy: 81.30%
# Epoch (85/130), Train Loss: 0.2251, Val Loss: 0.6783, Val Accuracy: 81.10%
# Epoch (86/130), Train Loss: 0.2252, Val Loss: 0.6728, Val Accuracy: 80.70%
# Epoch (87/130), Train Loss: 0.2257, Val Loss: 0.6812, Val Accuracy: 80.84%
# Epoch (88/130), Train Loss: 0.2210, Val Loss: 0.6935, Val Accuracy: 80.90%
# Epoch (89/130), Train Loss: 0.2208, Val Loss: 0.6785, Val Accuracy: 81.56%
# Epoch (90/130), Train Loss: 0.2173, Val Loss: 0.7078, Val Accuracy: 80.24%
# Epoch (91/130), Train Loss: 0.2053, Val Loss: 0.7122, Val Accuracy: 81.04%
# Epoch (92/130), Train Loss: 0.1980, Val Loss: 0.6894, Val Accuracy: 81.84%
# Epoch (93/130), Train Loss: 0.1983, Val Loss: 0.6966, Val Accuracy: 81.10%
# Epoch (94/130), Train Loss: 0.1934, Val Loss: 0.7192, Val Accuracy: 81.56%
# Epoch (95/130), Train Loss: 0.1953, Val Loss: 0.7251, Val Accuracy: 80.96%
# Epoch (96/130), Train Loss: 0.1904, Val Loss: 0.7050, Val Accuracy: 81.76%
# Epoch (97/130), Train Loss: 0.1887, Val Loss: 0.7130, Val Accuracy: 81.62%
# Epoch (98/130), Train Loss: 0.1919, Val Loss: 0.7066, Val Accuracy: 81.00%
# Epoch (99/130), Train Loss: 0.1918, Val Loss: 0.7153, Val Accuracy: 80.72%
# Epoch (100/130), Train Loss: 0.1836, Val Loss: 0.7032, Val Accuracy: 81.22%
# Epoch (101/130), Train Loss: 0.1855, Val Loss: 0.7019, Val Accuracy: 80.96%
# Epoch (102/130), Train Loss: 0.1860, Val Loss: 0.6776, Val Accuracy: 82.22%
# Epoch (103/130), Train Loss: 0.1864, Val Loss: 0.6660, Val Accuracy: 82.26%
# Epoch (104/130), Train Loss: 0.1798, Val Loss: 0.7196, Val Accuracy: 81.64%
# Epoch (105/130), Train Loss: 0.1842, Val Loss: 0.7115, Val Accuracy: 81.16%
# Epoch (106/130), Train Loss: 0.1834, Val Loss: 0.6975, Val Accuracy: 81.54%
# Epoch (107/130), Train Loss: 0.1798, Val Loss: 0.7088, Val Accuracy: 81.38%
# Epoch (108/130), Train Loss: 0.1869, Val Loss: 0.7357, Val Accuracy: 81.12%
# Epoch (109/130), Train Loss: 0.1796, Val Loss: 0.7008, Val Accuracy: 81.62%
# Epoch (110/130), Train Loss: 0.1777, Val Loss: 0.7239, Val Accuracy: 81.70%
# Epoch (111/130), Train Loss: 0.1790, Val Loss: 0.6978, Val Accuracy: 81.60%
# Epoch (112/130), Train Loss: 0.1764, Val Loss: 0.7099, Val Accuracy: 81.40%
# Epoch (113/130), Train Loss: 0.1800, Val Loss: 0.6910, Val Accuracy: 81.84%
# Epoch (114/130), Train Loss: 0.1744, Val Loss: 0.7386, Val Accuracy: 81.44%
# Epoch (115/130), Train Loss: 0.1759, Val Loss: 0.7107, Val Accuracy: 80.84%
# Epoch (116/130), Train Loss: 0.1749, Val Loss: 0.7219, Val Accuracy: 81.16%
# Epoch (117/130), Train Loss: 0.1734, Val Loss: 0.7421, Val Accuracy: 80.98%
# Epoch (118/130), Train Loss: 0.1763, Val Loss: 0.7547, Val Accuracy: 81.68%
# Epoch (119/130), Train Loss: 0.1711, Val Loss: 0.7382, Val Accuracy: 80.74%
# Epoch (120/130), Train Loss: 0.1681, Val Loss: 0.7240, Val Accuracy: 81.66%
# Epoch (121/130), Train Loss: 0.1646, Val Loss: 0.7384, Val Accuracy: 81.38%
# Epoch (122/130), Train Loss: 0.1605, Val Loss: 0.7132, Val Accuracy: 81.60%
# Epoch (123/130), Train Loss: 0.1621, Val Loss: 0.7169, Val Accuracy: 81.72%
# Epoch (124/130), Train Loss: 0.1595, Val Loss: 0.7690, Val Accuracy: 81.34%
# Epoch (125/130), Train Loss: 0.1575, Val Loss: 0.7394, Val Accuracy: 81.04%
# Epoch (126/130), Train Loss: 0.1620, Val Loss: 0.7285, Val Accuracy: 81.50%
# Epoch (127/130), Train Loss: 0.1557, Val Loss: 0.7614, Val Accuracy: 81.20%
# Epoch (128/130), Train Loss: 0.1567, Val Loss: 0.7696, Val Accuracy: 81.00%
# Epoch (129/130), Train Loss: 0.1571, Val Loss: 0.7527, Val Accuracy: 81.28%
# Epoch (130/130), Train Loss: 0.1583, Val Loss: 0.7519, Val Accuracy: 81.26%
# Highest Validation Accuracy: 82.26%

# %%
torch.save(net.state_dict(), 'trained_model.pth')

# %%
net = NeuralNet().to(device)
net.load_state_dict(torch.load('trained_model.pth'))
# Out:
# /tmp/ipykernel_152461/838394504.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   net.load_state_dict(torch.load('trained_model.pth'))
# <All keys matched successfully>

# %%
correct = 0
total = 0

net.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        outputs = net(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy: {100 * correct / total:.2f}%')
# Out:
# Accuracy: 80.38%

# %%
new_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

def load_image(image_path):
    image = Image.open(image_path)
    image = new_transform(image)
    image = image.unsqueeze(0)
    return image

image_paths = ['data/tests/ship.jpg', 'data/tests/cat.jpg', 'data/tests/dog.jpg']
images = [load_image(path).to(device) for path in image_paths]

net.eval()
with torch.no_grad():
    for i, image in enumerate(images):
        outputs = net(image)
        _, predicted = torch.max(outputs, 1)
        print(f'Image: {image_paths[i]}, Predicted class: {class_names[predicted.item()]}')
# Out:
# Image: ship.jpg, Predicted class: ship
# Image: cat.jpg, Predicted class: cat
# Image: dog.jpg, Predicted class: dog
